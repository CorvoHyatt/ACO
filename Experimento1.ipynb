# %%
from ACO import ACO
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import functools

# %% [markdown]
# # Leer grafo

# %%
import csv
graph = []
with open('10nodos.csv', 'r', newline='') as file:
    myreader = csv.reader(file, delimiter=',')
    for row in myreader:
        # Convierte cada elemento de la fila en un entero
        int_row = [int(cell) for cell in row]
        graph.append(int_row)
graph = np.array(graph)
n = len(graph)
G = nx.from_numpy_array(graph)
nx.draw(G, with_labels=True, node_color='orange', font_weight='bold')
plt.show()

# %% [markdown]
# # Funcion de Costo

# %%
def graph_coloring(solucion, graph):
	"""graph_coloring Función Objetivo para el problema de Graph Coloring

	Parameters
	----------
	solucion : list[int]
		La solución a evaluar codificada de forma combinatoria. Es de tamaño neces
	graph : networkx.classes.graph.Graph
		Es la matriz de adyacencias del grafo a analizar

	Returns
	-------
	int
		Retorna el costo de la función
	"""
	ncolores=len(set(solucion))
	conflicts = 0
	for u, v in graph.edges():
		if solucion[u] == solucion[v]:
			conflicts += 1
	return conflicts + ncolores

fn = functools.partial(graph_coloring,graph =G)

# %% [markdown]
# # Experimento 1

# %%
parametros = {
    "grafo": G,
    "num_colors":n,
    "num_ants":1,
    "max_iterations":300,
    "alpha": 1,
    "beta": 2,
    "rho": 0.1,
    "objective_function": graph_coloring
}

# %% [markdown]
# ## Prueba 1

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.09006 segundos
# Mejor coloreo: [3, 1, 3, 6, 9, 3, 6, 6, 2, 2]
# Valor objetivo: 5

# %% [markdown]
# ## Prueba 2

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.08883 segundos
# Mejor coloreo: [1, 6, 4, 2, 1, 8, 6, 4, 8, 1]
# Valor objetivo: 5

# %% [markdown]
# ## Prueba 3

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.08808 segundos
# Mejor coloreo: [2, 1, 9, 2, 9, 5, 1, 6, 4, 1]
# Valor objetivo: 6

# %% [markdown]
# ## Prueba 4

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.08675 segundos
# Mejor coloreo: [6, 3, 2, 6, 3, 2, 1, 1, 0, 3]
# Valor objetivo: 5

# %% [markdown]
# ## Prueba 5

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.08949 segundos
# Mejor coloreo: [7, 1, 2, 7, 1, 4, 2, 8, 8, 8]
# Valor objetivo: 5

# %% [markdown]
# ## Prueba 6

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.08735 segundos
# Mejor coloreo: [9, 6, 8, 5, 6, 2, 6, 5, 8, 6]
# Valor objetivo: 5

# %% [markdown]
# ## Prueba 7

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.10465 segundos
# Mejor coloreo: [2, 7, 5, 6, 2, 8, 6, 6, 5, 2]
# Valor objetivo: 5

# %% [markdown]
# ## Prueba 8

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.09400 segundos
# Mejor coloreo: [9, 0, 5, 9, 5, 5, 2, 8, 8, 2]
# Valor objetivo: 5

# %% [markdown]
# ## Prueba 9

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.08569 segundos
# Mejor coloreo: [0, 2, 3, 1, 2, 3, 8, 1, 1, 8]
# Valor objetivo: 6

# %% [markdown]
# ## Prueba 10

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 0.11316 segundos
# Mejor coloreo: [2, 3, 3, 6, 2, 5, 1, 1, 5, 2]
# Valor objetivo: 5
