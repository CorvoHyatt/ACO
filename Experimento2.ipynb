# %%
from ACO import ACO
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import functools

# %% [markdown]
# # Leer grafo

# %%
import csv
graph = []
with open('50nodos.csv', 'r', newline='') as file:
    myreader = csv.reader(file, delimiter=',')
    for row in myreader:
        # Convierte cada elemento de la fila en un entero
        int_row = [int(cell) for cell in row]
        graph.append(int_row)
graph = np.array(graph)
n = len(graph)
G = nx.from_numpy_array(graph)
nx.draw(G, with_labels=True, node_color='orange', font_weight='bold')
plt.show()

# %% [markdown]
# # Funcion de Costo

# %%
def graph_coloring(solucion, graph):
	"""graph_coloring Función Objetivo para el problema de Graph Coloring

	Parameters
	----------
	solucion : list[int]
		La solución a evaluar codificada de forma combinatoria. Es de tamaño neces
	graph : networkx.classes.graph.Graph
		Es la matriz de adyacencias del grafo a analizar

	Returns
	-------
	int
		Retorna el costo de la función
	"""
	ncolores=len(set(solucion))
	conflicts = 0
	for u, v in graph.edges():
		if solucion[u] == solucion[v]:
			conflicts += 1
	return conflicts + ncolores

fn = functools.partial(graph_coloring,graph =G)

# %% [markdown]
# # Experimento 2

# %%
parametros = {
    "grafo": G,
    "num_colors":n,
    "num_ants":3,
    "max_iterations":500,
    "alpha": 1,
    "beta": 2,
    "rho": 0.1,
    "objective_function": graph_coloring
}

# %% [markdown]
# ## Prueba 1

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 11.12922 segundos
# Mejor coloreo: [19, 6, 43, 34, 43, 8, 31, 20, 34, 1, 41, 24, 26, 16, 7, 5, 15, 49, 20, 1, 4, 19, 1, 32, 8, 3, 31, 19, 30, 24, 10, 1, 45, 0, 43, 47, 43, 24, 0, 32, 43, 27, 4, 24, 9, 24, 39, 20, 15, 27]
# Valor objetivo: 28

# %% [markdown]
# ## Pruba 2

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 11.51652 segundos
# Mejor coloreo: [26, 17, 10, 14, 38, 3, 8, 21, 19, 31, 42, 38, 23, 46, 37, 11, 2, 42, 14, 11, 8, 30, 31, 5, 16, 41, 20, 30, 41, 30, 36, 41, 26, 8, 45, 34, 5, 19, 43, 10, 8, 46, 36, 34, 12, 36, 2, 30, 2, 11]
# Valor objetivo: 26

# %% [markdown]
# ## Prueba 3

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 11.05614 segundos
# Mejor coloreo: [47, 2, 4, 30, 39, 40, 48, 12, 34, 48, 33, 47, 29, 14, 29, 44, 7, 1, 4, 45, 38, 4, 14, 41, 37, 43, 48, 43, 27, 9, 27, 33, 7, 25, 24, 4, 34, 39, 25, 30, 12, 34, 28, 7, 34, 14, 46, 24, 12, 4]
# Valor objetivo: 26

# %% [markdown]
# ## Prueba 4

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 11.11224 segundos
# Mejor coloreo: [44, 45, 18, 6, 24, 38, 20, 23, 23, 2, 6, 17, 2, 12, 46, 47, 39, 6, 41, 19, 35, 34, 39, 35, 45, 48, 19, 44, 13, 4, 5, 4, 41, 10, 24, 17, 28, 26, 20, 49, 10, 26, 46, 5, 47, 5, 11, 38, 45, 5]
# Valor objetivo: 27

# %% [markdown]
# ## Prueba 5

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 10.89313 segundos
# Mejor coloreo: [48, 47, 38, 8, 9, 46, 44, 45, 36, 20, 19, 12, 46, 6, 35, 1, 38, 35, 26, 37, 32, 12, 38, 38, 29, 36, 10, 16, 11, 12, 2, 18, 35, 44, 26, 24, 11, 6, 25, 14, 47, 9, 24, 2, 1, 25, 35, 11, 46, 47]
# Valor objetivo: 27

# %% [markdown]
# ## Prueba 6

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 11.35342 segundos
# Mejor coloreo: [13, 14, 9, 9, 19, 25, 17, 16, 3, 14, 17, 12, 40, 15, 13, 14, 24, 34, 19, 47, 44, 44, 5, 47, 46, 19, 4, 48, 28, 47, 5, 17, 36, 48, 39, 17, 12, 10, 42, 5, 3, 15, 45, 9, 30, 9, 4, 41, 3, 47]
# Valor objetivo: 27

# %% [markdown]
# ## Prueba 7

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 10.57518 segundos
# Mejor coloreo: [49, 1, 8, 44, 45, 44, 7, 44, 4, 13, 42, 45, 39, 26, 0, 41, 27, 34, 35, 1, 19, 48, 27, 15, 2, 26, 38, 43, 44, 32, 27, 3, 38, 39, 8, 7, 27, 35, 3, 0, 49, 35, 39, 38, 48, 41, 46, 8, 49, 18]
# Valor objetivo: 26

# %% [markdown]
# ## Prueba 8

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 10.83165 segundos
# Mejor coloreo: [5, 38, 26, 27, 12, 10, 20, 41, 27, 43, 33, 7, 19, 38, 32, 38, 26, 42, 44, 23, 30, 46, 20, 41, 35, 49, 35, 24, 49, 38, 41, 33, 27, 7, 39, 43, 11, 32, 22, 49, 42, 21, 36, 21, 12, 36, 21, 6, 17, 11]
# Valor objetivo: 28

# %% [markdown]
# ## Prueba 9

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 10.25843 segundos
# Mejor coloreo: [26, 17, 41, 14, 3, 19, 46, 44, 14, 39, 43, 45, 27, 33, 48, 26, 2, 15, 41, 31, 39, 33, 43, 26, 39, 20, 8, 0, 11, 3, 44, 11, 41, 2, 49, 15, 12, 29, 31, 6, 0, 15, 14, 49, 29, 44, 7, 43, 44, 15]
# Valor objetivo: 26

# %% [markdown]
# ## Prueba 10

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 10.40034 segundos
# Mejor coloreo: [8, 38, 1, 36, 1, 30, 1, 47, 0, 42, 39, 43, 28, 23, 41, 8, 27, 43, 37, 46, 40, 40, 6, 6, 47, 46, 43, 29, 48, 32, 46, 0, 0, 21, 4, 48, 4, 10, 38, 4, 39, 21, 29, 11, 39, 31, 3, 43, 43, 23]
# Valor objetivo: 27
