# %%
from ACO import ACO
import networkx as nx
import numpy as np
import matplotlib.pyplot as plt
import functools

# %% [markdown]
# # Leer grafo

# %%
import csv
graph = []
with open('125nodos.csv', 'r', newline='') as file:
    myreader = csv.reader(file, delimiter=',')
    for row in myreader:
        # Convierte cada elemento de la fila en un entero
        int_row = [int(cell) for cell in row]
        graph.append(int_row)
graph = np.array(graph)
n = len(graph)
G = nx.from_numpy_array(graph)
nx.draw(G, with_labels=True, node_color='orange', font_weight='bold')
plt.show()

# %% [markdown]
# # Funcion de Costo

# %%
def graph_coloring(solucion, graph):
	"""graph_coloring Función Objetivo para el problema de Graph Coloring

	Parameters
	----------
	solucion : list[int]
		La solución a evaluar codificada de forma combinatoria. Es de tamaño neces
	graph : networkx.classes.graph.Graph
		Es la matriz de adyacencias del grafo a analizar

	Returns
	-------
	int
		Retorna el costo de la función
	"""
	ncolores=len(set(solucion))
	conflicts = 0
	for u, v in graph.edges():
		if solucion[u] == solucion[v]:
			conflicts += 1
	return conflicts + ncolores

fn = functools.partial(graph_coloring,graph =G)

# %% [markdown]
# # Experimento 3

# %%
parametros = {
    "grafo": G,
    "num_colors":n,
    "num_ants":1,
    "max_iterations":300,
    "alpha": 1,
    "beta": 2,
    "rho": 0.1,
    "objective_function": graph_coloring
}

# %% [markdown]
# ## Prueba 1

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 16.08328 segundos
# Mejor coloreo: [79, 112, 45, 75, 20, 58, 98, 33, 116, 96, 13, 39, 29, 104, 39, 60, 48, 14, 66, 24, 89, 70, 18, 47, 43, 124, 99, 53, 7, 67, 31, 94, 105, 23, 74, 18, 20, 20, 32, 32, 54, 110, 103, 92, 94, 104, 112, 69, 83, 89, 56, 60, 13, 111, 70, 1, 43, 54, 0, 67, 64, 65, 119, 32, 7, 90, 89, 69, 29, 14, 103, 65, 0, 16, 70, 91, 50, 91, 108, 33, 94, 24, 75, 9, 91, 103, 89, 72, 86, 61, 92, 118, 1, 38, 105, 49, 103, 71, 90, 49, 105, 102, 78, 55, 20, 92, 11, 65, 7, 111, 75, 56, 81, 108, 40, 66, 73, 124, 57, 38, 66, 33, 99, 22, 106]
# Valor objetivo: 71

# %% [markdown]
# ## Prueba 2

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 15.82928 segundos
# Mejor coloreo: [97, 79, 43, 31, 123, 10, 11, 113, 6, 81, 87, 48, 119, 69, 11, 28, 36, 97, 82, 110, 10, 25, 108, 122, 37, 74, 63, 4, 114, 101, 4, 90, 54, 87, 100, 87, 92, 59, 30, 46, 76, 103, 30, 41, 17, 33, 60, 98, 54, 101, 37, 38, 30, 51, 88, 40, 15, 89, 54, 79, 5, 52, 5, 69, 6, 116, 108, 44, 76, 56, 19, 110, 67, 5, 68, 110, 97, 63, 36, 111, 115, 106, 59, 60, 123, 114, 76, 6, 31, 46, 38, 25, 92, 36, 82, 3, 90, 78, 9, 118, 10, 11, 122, 82, 84, 52, 112, 25, 103, 82, 82, 79, 57, 56, 69, 65, 11, 58, 80, 43, 26, 29, 19, 18, 68]
# Valor objetivo: 73

# %% [markdown]
# ## Prueba 3

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 17.15319 segundos
# Mejor coloreo: [51, 30, 5, 72, 72, 116, 27, 4, 37, 50, 41, 112, 90, 23, 101, 7, 57, 83, 33, 75, 106, 70, 101, 4, 111, 5, 98, 50, 5, 4, 90, 115, 78, 58, 88, 114, 82, 89, 91, 6, 36, 34, 69, 67, 15, 95, 60, 64, 38, 13, 120, 105, 16, 116, 93, 16, 73, 26, 14, 53, 68, 106, 56, 41, 10, 105, 62, 64, 53, 33, 12, 96, 14, 82, 72, 39, 97, 12, 72, 73, 35, 33, 59, 68, 83, 62, 119, 33, 115, 110, 89, 91, 65, 78, 109, 56, 10, 75, 27, 101, 123, 93, 79, 54, 27, 5, 72, 61, 69, 75, 27, 123, 98, 119, 49, 114, 10, 60, 7, 37, 97, 48, 31, 102, 13]
# Mejor coloreo: [37, 6, 89, 88, 89, 82, 96, 121, 33, 10, 67, 101, 15, 110, 48, 104, 24, 106, 88, 46, 65, 118, 104, 30, 86, 58, 24, 37, 38, 101, 23, 81, 30, 2, 44, 25, 88, 70, 121, 29, 99, 15, 5, 29, 76, 117, 99, 37, 46, 13, 56, 105, 94, 67, 123, 96, 8, 88, 70, 61, 46, 51, 92, 107, 24, 64, 96, 121, 2, 71, 104, 15, 65, 124, 3, 52, 87, 12, 56, 61, 12, 59, 71, 73, 6, 15, 81, 51, 42, 85, 101, 41, 103, 6, 123, 34, 117, 72, 105, 21, 9, 42, 10, 1, 103, 89, 35, 31, 27, 123, 23, 31, 83, 90, 74, 65, 86, 16, 64, 58, 21, 81, 119, 5, 117]
# Valor objetivo: 72

# %% [markdown]
# ## Prueba 8

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 19.15595 segundos
# Mejor coloreo: [9, 60, 72, 7, 43, 85, 79, 83, 31, 85, 123, 52, 33, 26, 89, 115, 63, 47, 68, 81, 98, 48, 17, 61, 27, 1, 83, 111, 101, 58, 1, 94, 74, 69, 80, 118, 68, 93, 33, 11, 50, 86, 103, 88, 12, 73, 99, 83, 88, 18, 67, 107, 48, 28, 9, 42, 98, 89, 20, 48, 73, 117, 55, 95, 9, 66, 28, 21, 124, 66, 35, 20, 75, 83, 7, 76, 85, 67, 48, 15, 27, 103, 91, 11, 42, 35, 27, 110, 29, 101, 47, 19, 61, 52, 43, 0, 59, 124, 85, 117, 16, 60, 70, 121, 13, 26, 27, 100, 75, 72, 118, 89, 66, 33, 49, 102, 28, 83, 85, 46, 93, 43, 45, 58, 31]
# Valor objetivo: 74

# %% [markdown]
# ## Prueba 9

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 18.35576 segundos
# Mejor coloreo: [6, 61, 91, 46, 80, 90, 5, 110, 76, 76, 122, 86, 90, 87, 57, 45, 79, 10, 52, 13, 20, 10, 73, 96, 75, 36, 22, 21, 34, 4, 45, 106, 57, 50, 7, 36, 75, 23, 30, 107, 83, 61, 102, 87, 60, 77, 46, 57, 79, 122, 19, 41, 113, 50, 7, 14, 47, 16, 82, 1, 65, 84, 38, 20, 52, 79, 58, 103, 20, 30, 47, 71, 7, 27, 122, 38, 93, 53, 17, 96, 16, 68, 87, 57, 67, 86, 5, 79, 114, 85, 93, 21, 16, 34, 80, 101, 69, 58, 113, 50, 61, 105, 64, 13, 0, 73, 32, 122, 88, 97, 5, 83, 103, 86, 1, 60, 61, 55, 98, 54, 2, 28, 20, 76, 86]
# Valor objetivo: 72

# %% [markdown]
# ## Prueba 10

# %%
aco = ACO(**parametros)
best_coloring, best_objective_value = aco.run()
print("Mejor coloreo:", best_coloring)
print("Valor objetivo:", best_objective_value)
plt.plot(range(len(aco._cost_best)), [x for x in aco._cost_best ], color ='orange', label ="Costo Best")
plt.grid(True, linestyle='dashed')
plt.xlabel('Generaciones')
plt.ylabel('Costo')
plt.title('ACO Algorithms')
plt.legend()
plt.show()
# Out:
# Tiempo de ejecución: 18.59570 segundos
# Mejor coloreo: [79, 23, 75, 73, 40, 119, 0, 10, 31, 93, 61, 23, 106, 68, 5, 67, 111, 27, 15, 93, 34, 50, 97, 75, 26, 53, 25, 40, 15, 13, 58, 106, 27, 99, 95, 62, 93, 97, 26, 54, 77, 111, 111, 26, 14, 13, 82, 36, 86, 42, 101, 53, 94, 5, 89, 70, 116, 108, 26, 26, 0, 21, 124, 43, 8, 35, 75, 9, 101, 18, 93, 86, 69, 102, 47, 14, 1, 20, 53, 27, 3, 100, 73, 89, 73, 7, 31, 16, 62, 15, 77, 38, 11, 37, 93, 71, 100, 26, 95, 34, 82, 40, 3, 111, 89, 55, 77, 18, 71, 22, 14, 97, 37, 109, 19, 7, 108, 25, 124, 72, 3, 50, 26, 13, 113]
# Valor objetivo: 68
